# %% [markdown]
# # International Trade

# %% [markdown]
# ## Imports

# %%
path = "../Data_Ryan"
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pmp_functions_v4 as pmp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 path = "../Data_Ryan"
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## Data

# %%
# --- Benchmark Data ---
benchmark_data = pd.read_excel(
    f"{path}/Equity Returns.xlsx",
    sheet_name = "WORLD - MXWO Index",
    index_col = 0,
    parse_dates = True
)

benchmark_data.index = pd.to_datetime(benchmark_data.index)

display(benchmark_data)
# Out:
#             Price (USD)
# Date
# 1970-01-30      94.2500
# 1970-02-27      96.9800
# 1970-03-31      97.0700
# 1970-04-30      87.8000
# 1970-05-29      82.0600
# ...                 ...
# 2025-07-31    8057.2246
# 2025-08-29    8269.7393
# 2025-09-30    8538.7900
# 2025-10-31    8711.4355
# 2025-11-28    8738.5645
#
# [671 rows x 1 columns]

# %%
# --- Load Factors Data ---
factors_data = pd.read_excel(
    f"{path}/Factors.xlsx",
    index_col = 0,
    parse_dates = True
)

factors_data.index = pd.to_datetime(factors_data.index, format='%Y%m')
factors_data.index = factors_data.index + pd.offsets.MonthEnd(0)
factors_data /= 100
display(factors_data)

# --- Riskfree Rate ---
riskfree = factors_data["RF"]
riskfree = riskfree.to_frame()
display(riskfree)
# Out:
# /var/folders/bl/ywj9s7j57_qf7pwls_sv_w9r0000gn/T/ipykernel_60586/2744343010.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   factors_data = pd.read_excel(
#             Mkt-RF     SMB     HML      RF
# 1926-07-31  0.0289 -0.0255 -0.0239  0.0022
# 1926-08-31  0.0264 -0.0114  0.0381  0.0025
# 1926-09-30  0.0038 -0.0136  0.0005  0.0023
# 1926-10-31 -0.0327 -0.0014  0.0082  0.0032
# 1926-11-30  0.0254 -0.0011 -0.0061  0.0031
# ...            ...     ...     ...     ...
# 2025-06-30  0.0486  0.0083 -0.0160  0.0034
# 2025-07-31  0.0198  0.0027 -0.0127  0.0034
# 2025-08-31  0.0184  0.0387  0.0442  0.0038
# 2025-09-30  0.0339 -0.0184 -0.0105  0.0033
# 2025-10-31  0.0195 -0.0055 -0.0310  0.0037
#
# [1192 rows x 4 columns]
#                 RF
# 1926-07-31  0.0022
# 1926-08-31  0.0025
# 1926-09-30  0.0023
# 1926-10-31  0.0032
# 1926-11-30  0.0031
# ...            ...
# 2025-06-30  0.0034
# 2025-07-31  0.0034
# 2025-08-31  0.0038
# 2025-09-30  0.0033
# 2025-10-31  0.0037
#
# [1192 rows x 1 columns]
